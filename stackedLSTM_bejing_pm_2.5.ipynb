# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import datetime as dt

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.preprocessing import StandardScaler, LabelEncoder

import torch
import torchvision
import torch.nn as nn
from torch.nn import functional as F
from torch.utils.tensorboard import SummaryWriter
from torch.utils.data import DataLoader, random_split, TensorDataset

# %matplotlib inline

# %%
np.random.seed(42)
device = 'cuda:2' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda:2'

# %% [markdown]
# ## Data Preprocessing

# %%
data = pd.read_csv('PRSA_data_2010.1.1-2014.12.31.csv', index_col=0)
data = data.fillna(0)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43824 entries, 1 to 43824
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    43824 non-null  int64
#  1   month   43824 non-null  int64
#  2   day     43824 non-null  int64
#  3   hour    43824 non-null  int64
#  4   pm2.5   43824 non-null  float64
#  5   DEWP    43824 non-null  int64
#  6   TEMP    43824 non-null  float64
#  7   PRES    43824 non-null  float64
#  8   cbwd    43824 non-null  object
#  9   Iws     43824 non-null  float64
#  10  Is      43824 non-null  int64
#  11  Ir      43824 non-null  int64
# dtypes: float64(4), int64(7), object(1)
# memory usage: 4.3+ MB

# %%
columns = ['pm2.5', 'DEWP', 'TEMP', 'PRES', 'Iws', 'Is', 'Ir']
scaler = StandardScaler()
transformed_data = data[['pm2.5', 'DEWP', 'TEMP', 'PRES', 'Iws', 'Is', 'Ir']]
transformed_data = scaler.fit_transform(transformed_data)
transformed_data = pd.DataFrame(transformed_data, columns=columns)
transformed_data.head()
# Out:
#       pm2.5      DEWP      TEMP      PRES       Iws        Is        Ir
# 0 -1.018534 -1.580878 -1.922250  0.443328 -0.441894 -0.069353 -0.137667
# 1 -1.018534 -1.580878 -2.004228  0.345943 -0.379306 -0.069353 -0.137667
# 2 -1.018534 -1.580878 -1.922250  0.248559 -0.343514 -0.069353 -0.137667
# 3 -1.018534 -1.580878 -2.168183  0.248559 -0.280926 -0.069353 -0.137667
# 4 -1.018534 -1.511594 -2.004228  0.151174 -0.218339 -0.069353 -0.137667

# %%
le = LabelEncoder()
cbwd = data['cbwd']
transformed_cbwd = le.fit_transform(cbwd)
transformed_data['cbwd'] = transformed_cbwd
transformed_data.head()
# Out:
#       pm2.5      DEWP      TEMP      PRES       Iws        Is        Ir  cbwd
# 0 -1.018534 -1.580878 -1.922250  0.443328 -0.441894 -0.069353 -0.137667     1
# 1 -1.018534 -1.580878 -2.004228  0.345943 -0.379306 -0.069353 -0.137667     1
# 2 -1.018534 -1.580878 -1.922250  0.248559 -0.343514 -0.069353 -0.137667     1
# 3 -1.018534 -1.580878 -2.168183  0.248559 -0.280926 -0.069353 -0.137667     1
# 4 -1.018534 -1.511594 -2.004228  0.151174 -0.218339 -0.069353 -0.137667     1

# %%
date_list = list()
for i in range(len(data)):
    year = int(data.iloc[i]['year'])
    month = int(data.iloc[i]['month'])
    day = int(data.iloc[i]['day'])
    hour = int(data.iloc[i]['hour'])
    date_list.append(dt.datetime(year, month, day, hour))
transformed_data.index = date_list
transformed_data.head()
# Out:
#                         pm2.5      DEWP      TEMP      PRES       Iws  \
# 2010-01-01 00:00:00 -1.018534 -1.580878 -1.922250  0.443328 -0.441894
# 2010-01-01 01:00:00 -1.018534 -1.580878 -2.004228  0.345943 -0.379306
# 2010-01-01 02:00:00 -1.018534 -1.580878 -1.922250  0.248559 -0.343514
# 2010-01-01 03:00:00 -1.018534 -1.580878 -2.168183  0.248559 -0.280926
# 2010-01-01 04:00:00 -1.018534 -1.511594 -2.004228  0.151174 -0.218339
#
#                            Is        Ir  cbwd
# 2010-01-01 00:00:00 -0.069353 -0.137667     1
# 2010-01-01 01:00:00 -0.069353 -0.137667     1
# 2010-01-01 02:00:00 -0.069353 -0.137667     1
# 2010-01-01 03:00:00 -0.069353 -0.137667     1
# 2010-01-01 04:00:00 -0.069353 -0.137667     1

# %% [markdown]
# ## data split

# %%
train_start = dt.datetime(2010, 1, 1, 0)
train_end = dt.datetime(2012, 12, 31, 23)
train = transformed_data.loc[train_start: train_end]

valid_start = dt.datetime(2013, 1, 1, 0)
valid_end = dt.datetime(2013, 12, 31, 23)
valid = transformed_data[valid_start: valid_end]

test_start = dt.datetime(2014, 1, 1, 0)
test_end = dt.datetime(2014, 12, 31 ,23)
test = transformed_data[test_start:test_end]

# %%
def dataprocessing(transformed_df):
    X_data, y_data = list(), list()
    for i in tqdm(range(0, len(transformed_df) - 36)):
        pm = transformed_df.iloc[i : i + 24]['pm2.5']
        dewp = transformed_df.iloc[i : i + 24]['DEWP']
        temp = transformed_df.iloc[i : i + 24]['TEMP']
        pres = transformed_df.iloc[i : i + 24]['PRES']
        lws = transformed_df.iloc[i : i + 24]['Iws']
        cbwd = transformed_df.iloc[i : i + 24]['cbwd']
        Is = transformed_df.iloc[i : i + 24]['Is']
        Ir = transformed_df.iloc[i : i + 24]['Ir']
        X_data.append([pm, dewp, temp, pres, lws, cbwd, Is, Ir])
        
        pm = transformed_df.iloc[i + 24]['pm2.5']
        y_data.append(pm)
#     print(X_data)
#     print(y_data)
    return torch.Tensor(X_data), torch.Tensor(y_data)

# %%
X_train, y_train = dataprocessing(train)
X_valid, y_valid = dataprocessing(valid)
X_test, y_test = dataprocessing(test)
# Out:
# 100%|██████████| 26268/26268 [06:30<00:00, 67.29it/s]
# 100%|██████████| 8724/8724 [01:56<00:00, 74.64it/s]
# 100%|██████████| 8724/8724 [01:59<00:00, 72.96it/s]

# %%
print('X Train shape ', X_train.shape)
print('X Valid shape ', X_valid.shape)
print('X Test shape', X_test.shape)
# Out:
# X Train shape  torch.Size([26268, 8, 24])
# X Valid shape  torch.Size([8724, 8, 24])
# X Test shape torch.Size([8724, 8, 24])

# %%
batch_size = 128

train_data = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_data, shuffle=False, batch_size=batch_size)

valid_data = TensorDataset(X_valid, y_valid)
valid_loader = DataLoader(valid_data, shuffle=False, batch_size=batch_size)

test_data = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_data, shuffle=False, batch_size=1)

# %% [markdown]
# ## Model

# %%
class MultivariateLSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(MultivariateLSTM, self).__init__()
        self.input_dim = input_dim
        self.hidden_dim1 = hidden_dim[0]
        self.hidden_dim2 = hidden_dim[1]
        
        self.lstm1 = nn.LSTM(input_dim, input_dim, batch_first=True)
        self.lstm2 = nn.LSTM(input_dim, self.hidden_dim1, batch_first=True)
        self.lstm3 = nn.LSTM(self.hidden_dim1, self.hidden_dim2, batch_first=True)
        
        self.fc1 = nn.Linear(8, 40)
        self.fc2 = nn.Linear(40, 35)
        self.fc3 = nn.Linear(35, 1)
        
    def forward(self, inp):
        h0, c0 = self.init_hidden(inp, self.input_dim)
        output, (h_t, c_t) = self.lstm1(inp, (h0, c0))
        h_t, c_t = self.fc1(h_t), self.fc1(c_t)
        output, (h_t, c_t) = self.lstm2(output, (h_t, c_t))
        h_t, c_t = self.fc2(h_t), self.fc2(c_t)
        output, (h_t, c_t) = self.lstm3(output, (h_t, c_t))
        output = self.fc3(h_t)
        return output
        
    def init_hidden(self, inp, c_size):
        b, seq_len, c = inp.size()
        h0 = torch.zeros(1, b, c_size)
        c0 = torch.zeros(1, b, c_size)
        return [t.cuda() for t in (h0, c0)]

# %%
with torch.no_grad():
    dataiter = iter(train_loader)
    X, y = dataiter.next()
    print(X.shape)
    print(y.shape)
    X = X.reshape(-1, 24, 8)
    model = MultivariateLSTM(8, [40, 35]).cuda()
    output = model(X.cuda())
    criterion = nn.MSELoss().cuda()
    print(output.shape)
    print(output)
    loss = criterion(output.squeeze(), y.cuda())
    print(loss)
# Out:
# torch.Size([128, 8, 24])
# torch.Size([128])
# torch.Size([1, 128, 1])
# tensor([[[-0.0093],
#          [-0.0099],
#          [-0.0088],
#          [-0.0090],
#          [-0.0099],
#          [-0.0107],
#          [-0.0091],
#          [-0.0074],
#          [-0.0091],
#          [-0.0092],
#          [-0.0108],
#          [-0.0126],
#          [-0.0097],
#          [-0.0097],
#          [-0.0079],
#          [-0.0087],
#          [-0.0092],
#          [-0.0087],
#          [-0.0097],
#          [-0.0117],
#          [-0.0095],
#          [-0.0096],
#          [-0.0087],
#          [-0.0100],
#          [-0.0090],
#          [-0.0091],
#          [-0.0097],
#          [-0.0111],
#          [-0.0092],
#          [-0.0094],
#          [-0.0076],
#          [-0.0083],
#          [-0.0053],
#          [-0.0049],
#          [-0.0045],
#          [-0.0054],
#          [-0.0058],
#          [-0.0061],
#          [-0.0059],
#          [-0.0050],
#          [-0.0028],
#          [-0.0022],
#          [-0.0031],
#          [-0.0038],
#          [-0.0039],
#          [-0.0056],
#          [-0.0065],
#          [-0.0070],
#          [-0.0083],
#          [-0.0093],
#          [-0.0106],
#          [-0.0100],
#          [-0.0106],
#          [-0.0088],
#          [-0.0089],
#          [-0.0089],
#          [-0.0100],
#          [-0.0119],
#          [-0.0127],
#          [-0.0099],
#          [-0.0111],
#          [-0.0091],
#          [-0.0094],
#          [-0.0079],
#          [-0.0086],
#          [-0.0102],
#          [-0.0106],
#          [-0.0082],
#          [-0.0096],
#          [-0.0072],
#          [-0.0089],
#          [-0.0089],
#          [-0.0089],
#          [-0.0089],
#          [-0.0090],
#          [-0.0090],
#          [-0.0090],
#          [-0.0090],
#          [-0.0088],
#          [-0.0085],
#          [-0.0089],
#          [-0.0090],
#          [-0.0088],
#          [-0.0087],
#          [-0.0083],
#          [-0.0091],
#          [-0.0089],
#          [-0.0091],
#          [-0.0093],
#          [-0.0085],
#          [-0.0090],
#          [-0.0095],
#          [-0.0089],
#          [-0.0092],
#          [-0.0086],
#          [-0.0090],
#          [-0.0092],
#          [-0.0086],
#          [-0.0090],
#          [-0.0090],
#          [-0.0089],
#          [-0.0091],
#          [-0.0086],
#          [-0.0088],
#          [-0.0088],
#          [-0.0087],
#          [-0.0090],
#          [-0.0090],
#          [-0.0091],
#          [-0.0090],
#          [-0.0088],
#          [-0.0091],
#          [-0.0088],
#          [-0.0092],
#          [-0.0087],
#          [-0.0092],
#          [-0.0098],
#          [-0.0093],
#          [-0.0085],
#          [-0.0086],
#          [-0.0092],
#          [-0.0092],
#          [-0.0092],
#          [-0.0090],
#          [-0.0090],
#          [-0.0087],
#          [-0.0092],
#          [-0.0094]]], device='cuda:0')
# tensor(0.3084, device='cuda:0')

# %% [markdown]
# ## Train

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='stackedLSTM_pm2.5(v1).pth', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
model = MultivariateLSTM(8, [40, 35]).cuda()

lr = 0.0001
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer,
                                                       mode='min',
                                                       factor=0.2
                                                    )
criterion = nn.MSELoss().cuda()
patience = 20
n_epochs = 300

print(model)
# Out:
# MultivariateLSTM(
#   (lstm1): LSTM(8, 8, batch_first=True)
#   (lstm2): LSTM(8, 40, batch_first=True)
#   (lstm3): LSTM(40, 35, batch_first=True)
#   (fc1): Linear(in_features=8, out_features=40, bias=True)
#   (fc2): Linear(in_features=40, out_features=35, bias=True)
#   (fc3): Linear(in_features=35, out_features=1, bias=True)
# )

# %%
def fit(model, batch_size, patience, n_epochs):
    
    train_losses = []
    valid_losses = []
    avg_train_losses = []
    avg_valid_losses = [] 
    
    early_stopping = EarlyStopping(patience=patience, verbose=True)
    
    for epoch in range(1, n_epochs + 1):

        ###################
        # train the model #
        ###################
        model.train()
        for data, target in train_loader:
            optimizer.zero_grad()
            data, target = data.reshape(-1, 24, 8).cuda(), target.cuda()
            output = model(data)
            loss = criterion(output.squeeze(), target)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())

        ######################    
        # validate the model #
        ######################
        model.eval()
        for data, target in valid_loader:
            data, target = data.reshape(-1, 24, 8).cuda(), target.cuda()
            output = model(data)
            loss = criterion(output.squeeze(), target)
            valid_losses.append(loss.item())

        train_loss = np.average(train_losses)
        valid_loss = np.average(valid_losses)
        avg_train_losses.append(train_loss)
        avg_valid_losses.append(valid_loss)
            
        epoch_len = len(str(n_epochs))
        
        print_msg = (f'[{epoch:>{epoch_len}}/{n_epochs:>{epoch_len}}] ' +
                     f'train_loss: {train_loss:.5f} ' +
                     f'valid_loss: {valid_loss:.5f}')
        
        print(print_msg)
        
        train_losses = []
        valid_losses = []
        early_stopping(valid_loss, model)
        
        if early_stopping.early_stop:
            print("Early stopping")
            break

    model.load_state_dict(torch.load('stackedLSTM_pm2.5(v1).pth'))

    return  model, avg_train_losses, avg_valid_losses

# %%
def evaluate_model(model, test_loader):
    test_loss = 0.0
    y_test = []
    y_hat = []
    model.eval()
    for data, target in test_loader:
        data, target = data.reshape(-1, 24, 8).cuda(), target.cuda()
        y_test.append(target.cpu().numpy())
        output = model(data)
        y_hat.append(output.detach().cpu().numpy())
        loss = criterion(output.reshape(1), target)
        test_loss += loss.item()
    return test_loss/len(test_loader), y_test, y_hat

# %%
model, train_loss, valid_loss = fit(model, batch_size, patience, n_epochs)
# Out:
# [  1/300] train_loss: 0.94870 valid_loss: 1.12362
# Validation loss decreased (inf --> 1.123619).  Saving model ...
# [  2/300] train_loss: 0.94427 valid_loss: 1.12747
# EarlyStopping counter: 1 out of 20
# [  3/300] train_loss: 0.94305 valid_loss: 1.13007
# EarlyStopping counter: 2 out of 20
# [  4/300] train_loss: 0.94267 valid_loss: 1.13138
# EarlyStopping counter: 3 out of 20
# [  5/300] train_loss: 0.94239 valid_loss: 1.13191
# EarlyStopping counter: 4 out of 20
# [  6/300] train_loss: 0.94194 valid_loss: 1.13198
# EarlyStopping counter: 5 out of 20
# [  7/300] train_loss: 0.94091 valid_loss: 1.13144
# EarlyStopping counter: 6 out of 20
# [  8/300] train_loss: 0.93707 valid_loss: 1.12795
# EarlyStopping counter: 7 out of 20
# [  9/300] train_loss: 0.92526 valid_loss: 1.10739
# Validation loss decreased (1.123619 --> 1.107385).  Saving model ...
# [ 10/300] train_loss: 0.89425 valid_loss: 1.07377
# Validation loss decreased (1.107385 --> 1.073765).  Saving model ...
# [ 11/300] train_loss: 0.83650 valid_loss: 1.03899
# Validation loss decreased (1.073765 --> 1.038993).  Saving model ...
# [ 12/300] train_loss: 0.81153 valid_loss: 1.01693
# Validation loss decreased (1.038993 --> 1.016934).  Saving model ...
# [ 13/300] train_loss: 0.80030 valid_loss: 1.00760
# Validation loss decreased (1.016934 --> 1.007602).  Saving model ...
# [ 14/300] train_loss: 0.79299 valid_loss: 1.00140
# Validation loss decreased (1.007602 --> 1.001405).  Saving model ...
# [ 15/300] train_loss: 0.78700 valid_loss: 0.99647
# Validation loss decreased (1.001405 --> 0.996469).  Saving model ...
# [ 16/300] train_loss: 0.78146 valid_loss: 0.99223
# Validation loss decreased (0.996469 --> 0.992235).  Saving model ...
# [ 17/300] train_loss: 0.77577 valid_loss: 0.98843
# Validation loss decreased (0.992235 --> 0.988433).  Saving model ...
# [ 18/300] train_loss: 0.76924 valid_loss: 0.98477
# Validation loss decreased (0.988433 --> 0.984768).  Saving model ...
# [ 19/300] train_loss: 0.76072 valid_loss: 0.98060
# Validation loss decreased (0.984768 --> 0.980603).  Saving model ...
# [ 20/300] train_loss: 0.74822 valid_loss: 0.97449
# Validation loss decreased (0.980603 --> 0.974489).  Saving model ...
# [ 21/300] train_loss: 0.72987 valid_loss: 0.96432
# Validation loss decreased (0.974489 --> 0.964325).  Saving model ...
# [ 22/300] train_loss: 0.70787 valid_loss: 0.94849
# Validation loss decreased (0.964325 --> 0.948493).  Saving model ...
# [ 23/300] train_loss: 0.68728 valid_loss: 0.92750
# Validation loss decreased (0.948493 --> 0.927500).  Saving model ...
# [ 24/300] train_loss: 0.66908 valid_loss: 0.90351
# Validation loss decreased (0.927500 --> 0.903507).  Saving model ...
# [ 25/300] train_loss: 0.65264 valid_loss: 0.87811
# Validation loss decreased (0.903507 --> 0.878108).  Saving model ...
# [ 26/300] train_loss: 0.63764 valid_loss: 0.85292
# Validation loss decreased (0.878108 --> 0.852920).  Saving model ...
# [ 27/300] train_loss: 0.62370 valid_loss: 0.82890
# Validation loss decreased (0.852920 --> 0.828899).  Saving model ...
# [ 28/300] train_loss: 0.61053 valid_loss: 0.80710
# Validation loss decreased (0.828899 --> 0.807099).  Saving model ...
# [ 29/300] train_loss: 0.59855 valid_loss: 0.78807
# Validation loss decreased (0.807099 --> 0.788071).  Saving model ...
# [ 30/300] train_loss: 0.58756 valid_loss: 0.76919
# Validation loss decreased (0.788071 --> 0.769192).  Saving model ...
# [ 31/300] train_loss: 0.57673 valid_loss: 0.74958
# Validation loss decreased (0.769192 --> 0.749582).  Saving model ...
# [ 32/300] train_loss: 0.56570 valid_loss: 0.72992
# Validation loss decreased (0.749582 --> 0.729921).  Saving model ...
# [ 33/300] train_loss: 0.55488 valid_loss: 0.71152
# Validation loss decreased (0.729921 --> 0.711519).  Saving model ...
# [ 34/300] train_loss: 0.54466 valid_loss: 0.69495
# Validation loss decreased (0.711519 --> 0.694947).  Saving model ...
# [ 35/300] train_loss: 0.53531 valid_loss: 0.68053
# Validation loss decreased (0.694947 --> 0.680534).  Saving model ...
# [ 36/300] train_loss: 0.52696 valid_loss: 0.66784
# Validation loss decreased (0.680534 --> 0.667836).  Saving model ...
# [ 37/300] train_loss: 0.51950 valid_loss: 0.65641
# Validation loss decreased (0.667836 --> 0.656412).  Saving model ...
# [ 38/300] train_loss: 0.51259 valid_loss: 0.64570
# Validation loss decreased (0.656412 --> 0.645703).  Saving model ...
# [ 39/300] train_loss: 0.50601 valid_loss: 0.63527
# Validation loss decreased (0.645703 --> 0.635266).  Saving model ...
# [ 40/300] train_loss: 0.49974 valid_loss: 0.62523
# Validation loss decreased (0.635266 --> 0.625234).  Saving model ...
# [ 41/300] train_loss: 0.49374 valid_loss: 0.61542
# Validation loss decreased (0.625234 --> 0.615419).  Saving model ...
# [ 42/300] train_loss: 0.48775 valid_loss: 0.60548
# Validation loss decreased (0.615419 --> 0.605477).  Saving model ...
# [ 43/300] train_loss: 0.48160 valid_loss: 0.59524
# Validation loss decreased (0.605477 --> 0.595239).  Saving model ...
# [ 44/300] train_loss: 0.47518 valid_loss: 0.58463
# Validation loss decreased (0.595239 --> 0.584630).  Saving model ...
# [ 45/300] train_loss: 0.46845 valid_loss: 0.57361
# Validation loss decreased (0.584630 --> 0.573610).  Saving model ...
# [ 46/300] train_loss: 0.46137 valid_loss: 0.56215
# Validation loss decreased (0.573610 --> 0.562153).  Saving model ...
# [ 47/300] train_loss: 0.45397 valid_loss: 0.55028
# Validation loss decreased (0.562153 --> 0.550277).  Saving model ...
# [ 48/300] train_loss: 0.44626 valid_loss: 0.53806
# Validation loss decreased (0.550277 --> 0.538058).  Saving model ...
# [ 49/300] train_loss: 0.43828 valid_loss: 0.52561
# Validation loss decreased (0.538058 --> 0.525606).  Saving model ...
# [ 50/300] train_loss: 0.43006 valid_loss: 0.51304
# Validation loss decreased (0.525606 --> 0.513036).  Saving model ...
# [ 51/300] train_loss: 0.42165 valid_loss: 0.50047
# Validation loss decreased (0.513036 --> 0.500473).  Saving model ...
# [ 52/300] train_loss: 0.41307 valid_loss: 0.48807
# Validation loss decreased (0.500473 --> 0.488069).  Saving model ...
# [ 53/300] train_loss: 0.40438 valid_loss: 0.47599
# Validation loss decreased (0.488069 --> 0.475992).  Saving model ...
# [ 54/300] train_loss: 0.39563 valid_loss: 0.46439
# Validation loss decreased (0.475992 --> 0.464390).  Saving model ...
# [ 55/300] train_loss: 0.38689 valid_loss: 0.45335
# Validation loss decreased (0.464390 --> 0.453346).  Saving model ...
# [ 56/300] train_loss: 0.37821 valid_loss: 0.44285
# Validation loss decreased (0.453346 --> 0.442852).  Saving model ...
# [ 57/300] train_loss: 0.36965 valid_loss: 0.43285
# Validation loss decreased (0.442852 --> 0.432849).  Saving model ...
# [ 58/300] train_loss: 0.36127 valid_loss: 0.42332
# Validation loss decreased (0.432849 --> 0.423320).  Saving model ...
# [ 59/300] train_loss: 0.35313 valid_loss: 0.41434
# Validation loss decreased (0.423320 --> 0.414345).  Saving model ...
# [ 60/300] train_loss: 0.34532 valid_loss: 0.40600
# Validation loss decreased (0.414345 --> 0.406000).  Saving model ...
# [ 61/300] train_loss: 0.33788 valid_loss: 0.39828
# Validation loss decreased (0.406000 --> 0.398284).  Saving model ...
# [ 62/300] train_loss: 0.33084 valid_loss: 0.39114
# Validation loss decreased (0.398284 --> 0.391143).  Saving model ...
# [ 63/300] train_loss: 0.32422 valid_loss: 0.38452
# Validation loss decreased (0.391143 --> 0.384518).  Saving model ...
# [ 64/300] train_loss: 0.31800 valid_loss: 0.37835
# Validation loss decreased (0.384518 --> 0.378345).  Saving model ...
# [ 65/300] train_loss: 0.31217 valid_loss: 0.37255
# Validation loss decreased (0.378345 --> 0.372546).  Saving model ...
# [ 66/300] train_loss: 0.30673 valid_loss: 0.36705
# Validation loss decreased (0.372546 --> 0.367052).  Saving model ...
# [ 67/300] train_loss: 0.30164 valid_loss: 0.36183
# Validation loss decreased (0.367052 --> 0.361832).  Saving model ...
# [ 68/300] train_loss: 0.29689 valid_loss: 0.35688
# Validation loss decreased (0.361832 --> 0.356882).  Saving model ...
# [ 69/300] train_loss: 0.29244 valid_loss: 0.35220
# Validation loss decreased (0.356882 --> 0.352196).  Saving model ...
# [ 70/300] train_loss: 0.28826 valid_loss: 0.34776
# Validation loss decreased (0.352196 --> 0.347758).  Saving model ...
# [ 71/300] train_loss: 0.28431 valid_loss: 0.34355
# Validation loss decreased (0.347758 --> 0.343550).  Saving model ...
# [ 72/300] train_loss: 0.28056 valid_loss: 0.33956
# Validation loss decreased (0.343550 --> 0.339557).  Saving model ...
# [ 73/300] train_loss: 0.27696 valid_loss: 0.33577
# Validation loss decreased (0.339557 --> 0.335767).  Saving model ...
# [ 74/300] train_loss: 0.27351 valid_loss: 0.33217
# Validation loss decreased (0.335767 --> 0.332168).  Saving model ...
# [ 75/300] train_loss: 0.27019 valid_loss: 0.32875
# Validation loss decreased (0.332168 --> 0.328749).  Saving model ...
# [ 76/300] train_loss: 0.26699 valid_loss: 0.32549
# Validation loss decreased (0.328749 --> 0.325492).  Saving model ...
# [ 77/300] train_loss: 0.26390 valid_loss: 0.32238
# Validation loss decreased (0.325492 --> 0.322379).  Saving model ...
# [ 78/300] train_loss: 0.26091 valid_loss: 0.31939
# Validation loss decreased (0.322379 --> 0.319388).  Saving model ...
# [ 79/300] train_loss: 0.25802 valid_loss: 0.31650
# Validation loss decreased (0.319388 --> 0.316500).  Saving model ...
# [ 80/300] train_loss: 0.25520 valid_loss: 0.31370
# Validation loss decreased (0.316500 --> 0.313698).  Saving model ...
# [ 81/300] train_loss: 0.25244 valid_loss: 0.31097
# Validation loss decreased (0.313698 --> 0.310968).  Saving model ...
# [ 82/300] train_loss: 0.24975 valid_loss: 0.30830
# Validation loss decreased (0.310968 --> 0.308299).  Saving model ...
# [ 83/300] train_loss: 0.24711 valid_loss: 0.30568
# Validation loss decreased (0.308299 --> 0.305684).  Saving model ...
# [ 84/300] train_loss: 0.24452 valid_loss: 0.30312
# Validation loss decreased (0.305684 --> 0.303116).  Saving model ...
# [ 85/300] train_loss: 0.24199 valid_loss: 0.30059
# Validation loss decreased (0.303116 --> 0.300589).  Saving model ...
# [ 86/300] train_loss: 0.23951 valid_loss: 0.29810
# Validation loss decreased (0.300589 --> 0.298102).  Saving model ...
# [ 87/300] train_loss: 0.23707 valid_loss: 0.29565
# Validation loss decreased (0.298102 --> 0.295651).  Saving model ...
# [ 88/300] train_loss: 0.23468 valid_loss: 0.29324
# Validation loss decreased (0.295651 --> 0.293236).  Saving model ...
# [ 89/300] train_loss: 0.23234 valid_loss: 0.29086
# Validation loss decreased (0.293236 --> 0.290858).  Saving model ...
# [ 90/300] train_loss: 0.23005 valid_loss: 0.28852
# Validation loss decreased (0.290858 --> 0.288519).  Saving model ...
# [ 91/300] train_loss: 0.22779 valid_loss: 0.28622
# Validation loss decreased (0.288519 --> 0.286219).  Saving model ...
# [ 92/300] train_loss: 0.22558 valid_loss: 0.28396
# Validation loss decreased (0.286219 --> 0.283961).  Saving model ...
# [ 93/300] train_loss: 0.22341 valid_loss: 0.28175
# Validation loss decreased (0.283961 --> 0.281745).  Saving model ...
# [ 94/300] train_loss: 0.22129 valid_loss: 0.27957
# Validation loss decreased (0.281745 --> 0.279573).  Saving model ...
# [ 95/300] train_loss: 0.21920 valid_loss: 0.27745
# Validation loss decreased (0.279573 --> 0.277447).  Saving model ...
# [ 96/300] train_loss: 0.21715 valid_loss: 0.27537
# Validation loss decreased (0.277447 --> 0.275366).  Saving model ...
# [ 97/300] train_loss: 0.21514 valid_loss: 0.27333
# Validation loss decreased (0.275366 --> 0.273332).  Saving model ...
# [ 98/300] train_loss: 0.21316 valid_loss: 0.27135
# Validation loss decreased (0.273332 --> 0.271346).  Saving model ...
# [ 99/300] train_loss: 0.21123 valid_loss: 0.26941
# Validation loss decreased (0.271346 --> 0.269407).  Saving model ...
# [100/300] train_loss: 0.20933 valid_loss: 0.26752
# Validation loss decreased (0.269407 --> 0.267515).  Saving model ...
# [101/300] train_loss: 0.20748 valid_loss: 0.26567
# Validation loss decreased (0.267515 --> 0.265671).  Saving model ...
# [102/300] train_loss: 0.20566 valid_loss: 0.26387
# Validation loss decreased (0.265671 --> 0.263871).  Saving model ...
# [103/300] train_loss: 0.20387 valid_loss: 0.26211
# Validation loss decreased (0.263871 --> 0.262114).  Saving model ...
# [104/300] train_loss: 0.20212 valid_loss: 0.26040
# Validation loss decreased (0.262114 --> 0.260399).  Saving model ...
# [105/300] train_loss: 0.20041 valid_loss: 0.25872
# Validation loss decreased (0.260399 --> 0.258721).  Saving model ...
# [106/300] train_loss: 0.19873 valid_loss: 0.25708
# Validation loss decreased (0.258721 --> 0.257078).  Saving model ...
# [107/300] train_loss: 0.19708 valid_loss: 0.25547
# Validation loss decreased (0.257078 --> 0.255468).  Saving model ...
# [108/300] train_loss: 0.19546 valid_loss: 0.25389
# Validation loss decreased (0.255468 --> 0.253888).  Saving model ...
# [109/300] train_loss: 0.19387 valid_loss: 0.25233
# Validation loss decreased (0.253888 --> 0.252335).  Saving model ...
# [110/300] train_loss: 0.19232 valid_loss: 0.25081
# Validation loss decreased (0.252335 --> 0.250808).  Saving model ...
# [111/300] train_loss: 0.19079 valid_loss: 0.24931
# Validation loss decreased (0.250808 --> 0.249307).  Saving model ...
# [112/300] train_loss: 0.18929 valid_loss: 0.24783
# Validation loss decreased (0.249307 --> 0.247830).  Saving model ...
# [113/300] train_loss: 0.18781 valid_loss: 0.24638
# Validation loss decreased (0.247830 --> 0.246376).  Saving model ...
# [114/300] train_loss: 0.18636 valid_loss: 0.24495
# Validation loss decreased (0.246376 --> 0.244947).  Saving model ...
# [115/300] train_loss: 0.18494 valid_loss: 0.24354
# Validation loss decreased (0.244947 --> 0.243540).  Saving model ...
# [116/300] train_loss: 0.18354 valid_loss: 0.24216
# Validation loss decreased (0.243540 --> 0.242156).  Saving model ...
# [117/300] train_loss: 0.18216 valid_loss: 0.24079
# Validation loss decreased (0.242156 --> 0.240794).  Saving model ...
# [118/300] train_loss: 0.18081 valid_loss: 0.23945
# Validation loss decreased (0.240794 --> 0.239453).  Saving model ...
# [119/300] train_loss: 0.17949 valid_loss: 0.23813
# Validation loss decreased (0.239453 --> 0.238133).  Saving model ...
# [120/300] train_loss: 0.17819 valid_loss: 0.23683
# Validation loss decreased (0.238133 --> 0.236832).  Saving model ...
# [121/300] train_loss: 0.17691 valid_loss: 0.23555
# Validation loss decreased (0.236832 --> 0.235550).  Saving model ...
# [122/300] train_loss: 0.17565 valid_loss: 0.23429
# Validation loss decreased (0.235550 --> 0.234285).  Saving model ...
# [123/300] train_loss: 0.17442 valid_loss: 0.23304
# Validation loss decreased (0.234285 --> 0.233039).  Saving model ...
# [124/300] train_loss: 0.17321 valid_loss: 0.23181
# Validation loss decreased (0.233039 --> 0.231811).  Saving model ...
# [125/300] train_loss: 0.17202 valid_loss: 0.23060
# Validation loss decreased (0.231811 --> 0.230598).  Saving model ...
# [126/300] train_loss: 0.17086 valid_loss: 0.22940
# Validation loss decreased (0.230598 --> 0.229402).  Saving model ...
# [127/300] train_loss: 0.16971 valid_loss: 0.22822
# Validation loss decreased (0.229402 --> 0.228225).  Saving model ...
# [128/300] train_loss: 0.16859 valid_loss: 0.22707
# Validation loss decreased (0.228225 --> 0.227070).  Saving model ...
# [129/300] train_loss: 0.16749 valid_loss: 0.22594
# Validation loss decreased (0.227070 --> 0.225941).  Saving model ...
# [130/300] train_loss: 0.16641 valid_loss: 0.22484
# Validation loss decreased (0.225941 --> 0.224840).  Saving model ...
# [131/300] train_loss: 0.16536 valid_loss: 0.22377
# Validation loss decreased (0.224840 --> 0.223766).  Saving model ...
# [132/300] train_loss: 0.16434 valid_loss: 0.22271
# Validation loss decreased (0.223766 --> 0.222714).  Saving model ...
# [133/300] train_loss: 0.16333 valid_loss: 0.22168
# Validation loss decreased (0.222714 --> 0.221681).  Saving model ...
# [134/300] train_loss: 0.16235 valid_loss: 0.22066
# Validation loss decreased (0.221681 --> 0.220664).  Saving model ...
# [135/300] train_loss: 0.16139 valid_loss: 0.21966
# Validation loss decreased (0.220664 --> 0.219662).  Saving model ...
# [136/300] train_loss: 0.16046 valid_loss: 0.21868
# Validation loss decreased (0.219662 --> 0.218676).  Saving model ...
# [137/300] train_loss: 0.15954 valid_loss: 0.21770
# Validation loss decreased (0.218676 --> 0.217704).  Saving model ...
# [138/300] train_loss: 0.15865 valid_loss: 0.21675
# Validation loss decreased (0.217704 --> 0.216747).  Saving model ...
# [139/300] train_loss: 0.15777 valid_loss: 0.21580
# Validation loss decreased (0.216747 --> 0.215802).  Saving model ...
# [140/300] train_loss: 0.15692 valid_loss: 0.21487
# Validation loss decreased (0.215802 --> 0.214870).  Saving model ...
# [141/300] train_loss: 0.15609 valid_loss: 0.21395
# Validation loss decreased (0.214870 --> 0.213948).  Saving model ...
# [142/300] train_loss: 0.15528 valid_loss: 0.21304
# Validation loss decreased (0.213948 --> 0.213037).  Saving model ...
# [143/300] train_loss: 0.15449 valid_loss: 0.21213
# Validation loss decreased (0.213037 --> 0.212134).  Saving model ...
# [144/300] train_loss: 0.15371 valid_loss: 0.21124
# Validation loss decreased (0.212134 --> 0.211241).  Saving model ...
# [145/300] train_loss: 0.15296 valid_loss: 0.21036
# Validation loss decreased (0.211241 --> 0.210358).  Saving model ...
# [146/300] train_loss: 0.15222 valid_loss: 0.20949
# Validation loss decreased (0.210358 --> 0.209486).  Saving model ...
# [147/300] train_loss: 0.15150 valid_loss: 0.20863
# Validation loss decreased (0.209486 --> 0.208627).  Saving model ...
# [148/300] train_loss: 0.15079 valid_loss: 0.20778
# Validation loss decreased (0.208627 --> 0.207781).  Saving model ...
# [149/300] train_loss: 0.15010 valid_loss: 0.20695
# Validation loss decreased (0.207781 --> 0.206949).  Saving model ...
# [150/300] train_loss: 0.14943 valid_loss: 0.20613
# Validation loss decreased (0.206949 --> 0.206133).  Saving model ...
# [151/300] train_loss: 0.14878 valid_loss: 0.20533
# Validation loss decreased (0.206133 --> 0.205331).  Saving model ...
# [152/300] train_loss: 0.14814 valid_loss: 0.20454
# Validation loss decreased (0.205331 --> 0.204545).  Saving model ...
# [153/300] train_loss: 0.14751 valid_loss: 0.20377
# Validation loss decreased (0.204545 --> 0.203774).  Saving model ...
# [154/300] train_loss: 0.14690 valid_loss: 0.20302
# Validation loss decreased (0.203774 --> 0.203018).  Saving model ...
# [155/300] train_loss: 0.14631 valid_loss: 0.20228
# Validation loss decreased (0.203018 --> 0.202276).  Saving model ...
# [156/300] train_loss: 0.14573 valid_loss: 0.20155
# Validation loss decreased (0.202276 --> 0.201548).  Saving model ...
# [157/300] train_loss: 0.14516 valid_loss: 0.20083
# Validation loss decreased (0.201548 --> 0.200834).  Saving model ...
# [158/300] train_loss: 0.14460 valid_loss: 0.20013
# Validation loss decreased (0.200834 --> 0.200133).  Saving model ...
# [159/300] train_loss: 0.14406 valid_loss: 0.19944
# Validation loss decreased (0.200133 --> 0.199443).  Saving model ...
# [160/300] train_loss: 0.14353 valid_loss: 0.19876
# Validation loss decreased (0.199443 --> 0.198764).  Saving model ...
# [161/300] train_loss: 0.14300 valid_loss: 0.19810
# Validation loss decreased (0.198764 --> 0.198095).  Saving model ...
# [162/300] train_loss: 0.14249 valid_loss: 0.19744
# Validation loss decreased (0.198095 --> 0.197436).  Saving model ...
# [163/300] train_loss: 0.14199 valid_loss: 0.19678
# Validation loss decreased (0.197436 --> 0.196784).  Saving model ...
# [164/300] train_loss: 0.14149 valid_loss: 0.19614
# Validation loss decreased (0.196784 --> 0.196141).  Saving model ...
# [165/300] train_loss: 0.14100 valid_loss: 0.19551
# Validation loss decreased (0.196141 --> 0.195507).  Saving model ...
# [166/300] train_loss: 0.14052 valid_loss: 0.19488
# Validation loss decreased (0.195507 --> 0.194881).  Saving model ...
# [167/300] train_loss: 0.14005 valid_loss: 0.19426
# Validation loss decreased (0.194881 --> 0.194265).  Saving model ...
# [168/300] train_loss: 0.13959 valid_loss: 0.19366
# Validation loss decreased (0.194265 --> 0.193658).  Saving model ...
# [169/300] train_loss: 0.13913 valid_loss: 0.19306
# Validation loss decreased (0.193658 --> 0.193062).  Saving model ...
# [170/300] train_loss: 0.13867 valid_loss: 0.19248
# Validation loss decreased (0.193062 --> 0.192475).  Saving model ...
# [171/300] train_loss: 0.13823 valid_loss: 0.19190
# Validation loss decreased (0.192475 --> 0.191899).  Saving model ...
# [172/300] train_loss: 0.13779 valid_loss: 0.19133
# Validation loss decreased (0.191899 --> 0.191332).  Saving model ...
# [173/300] train_loss: 0.13736 valid_loss: 0.19077
# Validation loss decreased (0.191332 --> 0.190773).  Saving model ...
# [174/300] train_loss: 0.13693 valid_loss: 0.19022
# Validation loss decreased (0.190773 --> 0.190222).  Saving model ...
# [175/300] train_loss: 0.13651 valid_loss: 0.18968
# Validation loss decreased (0.190222 --> 0.189677).  Saving model ...
# [176/300] train_loss: 0.13609 valid_loss: 0.18914
# Validation loss decreased (0.189677 --> 0.189138).  Saving model ...
# [177/300] train_loss: 0.13567 valid_loss: 0.18860
# Validation loss decreased (0.189138 --> 0.188603).  Saving model ...
# [178/300] train_loss: 0.13526 valid_loss: 0.18807
# Validation loss decreased (0.188603 --> 0.188073).  Saving model ...
# [179/300] train_loss: 0.13485 valid_loss: 0.18755
# Validation loss decreased (0.188073 --> 0.187548).  Saving model ...
# [180/300] train_loss: 0.13445 valid_loss: 0.18703
# Validation loss decreased (0.187548 --> 0.187027).  Saving model ...
# [181/300] train_loss: 0.13405 valid_loss: 0.18651
# Validation loss decreased (0.187027 --> 0.186512).  Saving model ...
# [182/300] train_loss: 0.13365 valid_loss: 0.18600
# Validation loss decreased (0.186512 --> 0.186002).  Saving model ...
# [183/300] train_loss: 0.13326 valid_loss: 0.18550
# Validation loss decreased (0.186002 --> 0.185498).  Saving model ...
# [184/300] train_loss: 0.13286 valid_loss: 0.18500
# Validation loss decreased (0.185498 --> 0.185000).  Saving model ...
# [185/300] train_loss: 0.13248 valid_loss: 0.18451
# Validation loss decreased (0.185000 --> 0.184509).  Saving model ...
# [186/300] train_loss: 0.13209 valid_loss: 0.18402
# Validation loss decreased (0.184509 --> 0.184024).  Saving model ...
# [187/300] train_loss: 0.13171 valid_loss: 0.18354
# Validation loss decreased (0.184024 --> 0.183544).  Saving model ...
# [188/300] train_loss: 0.13133 valid_loss: 0.18307
# Validation loss decreased (0.183544 --> 0.183068).  Saving model ...
# [189/300] train_loss: 0.13095 valid_loss: 0.18260
# Validation loss decreased (0.183068 --> 0.182596).  Saving model ...
# [190/300] train_loss: 0.13058 valid_loss: 0.18213
# Validation loss decreased (0.182596 --> 0.182127).  Saving model ...
# [191/300] train_loss: 0.13021 valid_loss: 0.18166
# Validation loss decreased (0.182127 --> 0.181659).  Saving model ...
# [192/300] train_loss: 0.12984 valid_loss: 0.18119
# Validation loss decreased (0.181659 --> 0.181192).  Saving model ...
# [193/300] train_loss: 0.12947 valid_loss: 0.18073
# Validation loss decreased (0.181192 --> 0.180725).  Saving model ...
# [194/300] train_loss: 0.12910 valid_loss: 0.18026
# Validation loss decreased (0.180725 --> 0.180259).  Saving model ...
# [195/300] train_loss: 0.12874 valid_loss: 0.17979
# Validation loss decreased (0.180259 --> 0.179793).  Saving model ...
# [196/300] train_loss: 0.12837 valid_loss: 0.17933
# Validation loss decreased (0.179793 --> 0.179328).  Saving model ...
# [197/300] train_loss: 0.12801 valid_loss: 0.17887
# Validation loss decreased (0.179328 --> 0.178865).  Saving model ...
# [198/300] train_loss: 0.12764 valid_loss: 0.17841
# Validation loss decreased (0.178865 --> 0.178405).  Saving model ...
# [199/300] train_loss: 0.12728 valid_loss: 0.17795
# Validation loss decreased (0.178405 --> 0.177950).  Saving model ...
# [200/300] train_loss: 0.12692 valid_loss: 0.17750
# Validation loss decreased (0.177950 --> 0.177501).  Saving model ...
# [201/300] train_loss: 0.12656 valid_loss: 0.17706
# Validation loss decreased (0.177501 --> 0.177060).  Saving model ...
# [202/300] train_loss: 0.12621 valid_loss: 0.17663
# Validation loss decreased (0.177060 --> 0.176629).  Saving model ...
# [203/300] train_loss: 0.12585 valid_loss: 0.17621
# Validation loss decreased (0.176629 --> 0.176210).  Saving model ...
# [204/300] train_loss: 0.12550 valid_loss: 0.17580
# Validation loss decreased (0.176210 --> 0.175804).  Saving model ...
# [205/300] train_loss: 0.12516 valid_loss: 0.17541
# Validation loss decreased (0.175804 --> 0.175409).  Saving model ...
# [206/300] train_loss: 0.12481 valid_loss: 0.17502
# Validation loss decreased (0.175409 --> 0.175025).  Saving model ...
# [207/300] train_loss: 0.12447 valid_loss: 0.17465
# Validation loss decreased (0.175025 --> 0.174649).  Saving model ...
# [208/300] train_loss: 0.12414 valid_loss: 0.17428
# Validation loss decreased (0.174649 --> 0.174279).  Saving model ...
# [209/300] train_loss: 0.12380 valid_loss: 0.17391
# Validation loss decreased (0.174279 --> 0.173912).  Saving model ...
# [210/300] train_loss: 0.12347 valid_loss: 0.17355
# Validation loss decreased (0.173912 --> 0.173545).  Saving model ...
# [211/300] train_loss: 0.12314 valid_loss: 0.17317
# Validation loss decreased (0.173545 --> 0.173175).  Saving model ...
# [212/300] train_loss: 0.12281 valid_loss: 0.17280
# Validation loss decreased (0.173175 --> 0.172799).  Saving model ...
# [213/300] train_loss: 0.12248 valid_loss: 0.17242
# Validation loss decreased (0.172799 --> 0.172417).  Saving model ...
# [214/300] train_loss: 0.12215 valid_loss: 0.17203
# Validation loss decreased (0.172417 --> 0.172026).  Saving model ...
# [215/300] train_loss: 0.12182 valid_loss: 0.17163
# Validation loss decreased (0.172026 --> 0.171628).  Saving model ...
# [216/300] train_loss: 0.12149 valid_loss: 0.17122
# Validation loss decreased (0.171628 --> 0.171222).  Saving model ...
# [217/300] train_loss: 0.12116 valid_loss: 0.17081
# Validation loss decreased (0.171222 --> 0.170811).  Saving model ...
# [218/300] train_loss: 0.12083 valid_loss: 0.17039
# Validation loss decreased (0.170811 --> 0.170395).  Saving model ...
# [219/300] train_loss: 0.12050 valid_loss: 0.16998
# Validation loss decreased (0.170395 --> 0.169977).  Saving model ...
# [220/300] train_loss: 0.12017 valid_loss: 0.16956
# Validation loss decreased (0.169977 --> 0.169559).  Saving model ...
# [221/300] train_loss: 0.11984 valid_loss: 0.16914
# Validation loss decreased (0.169559 --> 0.169143).  Saving model ...
# [222/300] train_loss: 0.11951 valid_loss: 0.16873
# Validation loss decreased (0.169143 --> 0.168732).  Saving model ...
# [223/300] train_loss: 0.11919 valid_loss: 0.16833
# Validation loss decreased (0.168732 --> 0.168326).  Saving model ...
# [224/300] train_loss: 0.11886 valid_loss: 0.16793
# Validation loss decreased (0.168326 --> 0.167927).  Saving model ...
# [225/300] train_loss: 0.11854 valid_loss: 0.16753
# Validation loss decreased (0.167927 --> 0.167535).  Saving model ...
# [226/300] train_loss: 0.11822 valid_loss: 0.16715
# Validation loss decreased (0.167535 --> 0.167149).  Saving model ...
# [227/300] train_loss: 0.11791 valid_loss: 0.16677
# Validation loss decreased (0.167149 --> 0.166769).  Saving model ...
# [228/300] train_loss: 0.11760 valid_loss: 0.16639
# Validation loss decreased (0.166769 --> 0.166394).  Saving model ...
# [229/300] train_loss: 0.11729 valid_loss: 0.16602
# Validation loss decreased (0.166394 --> 0.166019).  Saving model ...
# [230/300] train_loss: 0.11698 valid_loss: 0.16564
# Validation loss decreased (0.166019 --> 0.165643).  Saving model ...
# [231/300] train_loss: 0.11668 valid_loss: 0.16526
# Validation loss decreased (0.165643 --> 0.165261).  Saving model ...
# [232/300] train_loss: 0.11637 valid_loss: 0.16487
# Validation loss decreased (0.165261 --> 0.164869).  Saving model ...
# [233/300] train_loss: 0.11607 valid_loss: 0.16446
# Validation loss decreased (0.164869 --> 0.164460).  Saving model ...
# [234/300] train_loss: 0.11577 valid_loss: 0.16403
# Validation loss decreased (0.164460 --> 0.164027).  Saving model ...
# [235/300] train_loss: 0.11546 valid_loss: 0.16356
# Validation loss decreased (0.164027 --> 0.163563).  Saving model ...
# [236/300] train_loss: 0.11515 valid_loss: 0.16306
# Validation loss decreased (0.163563 --> 0.163055).  Saving model ...
# [237/300] train_loss: 0.11483 valid_loss: 0.16249
# Validation loss decreased (0.163055 --> 0.162492).  Saving model ...
# [238/300] train_loss: 0.11450 valid_loss: 0.16185
# Validation loss decreased (0.162492 --> 0.161854).  Saving model ...
# [239/300] train_loss: 0.11416 valid_loss: 0.16112
# Validation loss decreased (0.161854 --> 0.161120).  Saving model ...
# [240/300] train_loss: 0.11381 valid_loss: 0.16026
# Validation loss decreased (0.161120 --> 0.160255).  Saving model ...
# [241/300] train_loss: 0.11343 valid_loss: 0.15922
# Validation loss decreased (0.160255 --> 0.159216).  Saving model ...
# [242/300] train_loss: 0.11301 valid_loss: 0.15794
# Validation loss decreased (0.159216 --> 0.157941).  Saving model ...
# [243/300] train_loss: 0.11256 valid_loss: 0.15635
# Validation loss decreased (0.157941 --> 0.156349).  Saving model ...
# [244/300] train_loss: 0.11205 valid_loss: 0.15436
# Validation loss decreased (0.156349 --> 0.154365).  Saving model ...
# [245/300] train_loss: 0.11147 valid_loss: 0.15202
# Validation loss decreased (0.154365 --> 0.152025).  Saving model ...
# [246/300] train_loss: 0.11085 valid_loss: 0.14994
# Validation loss decreased (0.152025 --> 0.149937).  Saving model ...
# [247/300] train_loss: 0.11033 valid_loss: 0.15079
# EarlyStopping counter: 1 out of 20
# [248/300] train_loss: 0.11051 valid_loss: 0.16229
# EarlyStopping counter: 2 out of 20
# [249/300] train_loss: 0.11305 valid_loss: 0.19283
# EarlyStopping counter: 3 out of 20
# [250/300] train_loss: 0.12108 valid_loss: 0.22094
# EarlyStopping counter: 4 out of 20
# [251/300] train_loss: 0.13200 valid_loss: 0.20851
# EarlyStopping counter: 5 out of 20
# [252/300] train_loss: 0.13009 valid_loss: 0.22145
# EarlyStopping counter: 6 out of 20
# [253/300] train_loss: 0.13254 valid_loss: 0.22600
# EarlyStopping counter: 7 out of 20
# [254/300] train_loss: 0.13602 valid_loss: 0.20177
# EarlyStopping counter: 8 out of 20
# [255/300] train_loss: 0.12921 valid_loss: 0.18659
# EarlyStopping counter: 9 out of 20
# [256/300] train_loss: 0.12271 valid_loss: 0.18209
# EarlyStopping counter: 10 out of 20
# [257/300] train_loss: 0.11972 valid_loss: 0.18113
# EarlyStopping counter: 11 out of 20
# [258/300] train_loss: 0.11855 valid_loss: 0.18161
# EarlyStopping counter: 12 out of 20
# [259/300] train_loss: 0.11825 valid_loss: 0.18261
# EarlyStopping counter: 13 out of 20
# [260/300] train_loss: 0.11835 valid_loss: 0.18340
# EarlyStopping counter: 14 out of 20
# [261/300] train_loss: 0.11849 valid_loss: 0.18353
# EarlyStopping counter: 15 out of 20
# [262/300] train_loss: 0.11844 valid_loss: 0.18300
# EarlyStopping counter: 16 out of 20
# [263/300] train_loss: 0.11816 valid_loss: 0.18208
# EarlyStopping counter: 17 out of 20
# [264/300] train_loss: 0.11771 valid_loss: 0.18102
# EarlyStopping counter: 18 out of 20
# [265/300] train_loss: 0.11719 valid_loss: 0.18000
# EarlyStopping counter: 19 out of 20
# [266/300] train_loss: 0.11668 valid_loss: 0.17912
# EarlyStopping counter: 20 out of 20
# Early stopping

# %%
model.load_state_dict(torch.load('stackedLSTM_pm2.5(v1).pth'))
# Out:
# <All keys matched successfully>

# %%
test_loss, y_test, y_hat = evaluate_model(model, test_loader)

# %%
test_loss
# Out:
# 0.10245632597349454

# %%
target, predicted = list(), list()
for i in range(len(y_test)):
    target.append(y_test[i].item())
    predicted.append(y_hat[i][0].item())

# %%
plt.figure(figsize=(10, 3))
plt.plot(target[200:400], label='target')
plt.plot(predicted[200:400], label='predicted')
plt.legend(loc='upper left', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10, 3))
plt.plot(target[200:300], label='target')
plt.plot(predicted[200:300], label='predicted')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(target, label='target')
plt.plot(predicted, label='predicted')
plt.legend()
plt.show()
